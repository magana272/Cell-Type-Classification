# %% [markdown]
# <a href="https://colab.research.google.com/github/magana272/CellTypeClassification/blob/experiment/Run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import torch
# !git clone -b refactor https://github.com/magana272/CellTypeClassification.git
sys.path.append('/content/CellTypeClassification')
# !pip install scanpy torch_geometric faiss-gpu-cu13 optuna alive_progress
# !pip install torch_geometric optuna scanpy GEOparse leidenalg
# Out:
# Cloning into 'CellTypeClassification'...
# remote: Enumerating objects: 1194, done.
# remote: Counting objects: 100% (453/453), done.
# remote: Compressing objects: 100% (236/236), done.
# remote: Total 1194 (delta 338), reused 317 (delta 217), pack-reused 741 (from 1)
# Receiving objects: 100% (1194/1194), 29.59 MiB | 31.11 MiB/s, done.
# Resolving deltas: 100% (778/778), done.
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.0 MB/s eta 0:00:00
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Collecting scanpy
#   Downloading scanpy-1.12.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting GEOparse
#   Downloading GEOparse-2.0.4-py3-none-any.whl.metadata (6.5 kB)
# Collecting leidenalg
#   Downloading leidenalg-0.11.0-cp38-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.13.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Collecting anndata>=0.10.8 (from scanpy)
#   Downloading anndata-0.12.10-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from scanpy) (2026.2.25)
# Collecting fast-array-utils>=1.4 (from fast-array-utils[accel,sparse]>=1.4->scanpy)
#   Downloading fast_array_utils-1.4.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.5.3)
# Collecting legacy-api-wrap>=1.5 (from scanpy)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.60.0)
# Collecting pandas>=2.3 (from scanpy)
#   Downloading pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.13.2)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.4.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.14.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.12 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.12)
# Collecting igraph<2.0,>=1.0.0 (from leidenalg)
#   Downloading igraph-1.0.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.10.8->scanpy)
#   Downloading array_api_compat-1.14.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pandas>=2.3 (from scanpy)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 13.0 MB/s eta 0:00:00
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.10.8->scanpy)
#   Downloading zarr-3.1.6-py3-none-any.whl.metadata (8.6 kB)
# Collecting texttable>=1.6.2 (from igraph<2.0,>=1.0.0->leidenalg)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3->scanpy) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->scanpy) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9->scanpy) (1.17.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.6 MB/s eta 0:00:00
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 29.3 MB/s eta 0:00:00
# Downloading scanpy-1.12.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 111.5 MB/s eta 0:00:00
# Downloading GEOparse-2.0.4-py3-none-any.whl (29 kB)
# Downloading leidenalg-0.11.0-cp38-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 141.0 MB/s eta 0:00:00
# Downloading anndata-0.12.10-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.6/176.6 kB 4.3 MB/s eta 0:00:00
# Downloading fast_array_utils-1.4.1-py3-none-any.whl (39 kB)
# Downloading igraph-1.0.0-cp39-abi3-manylinux_2_28_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 74.7 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 184.1 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading session_info2-0.4.1-py3-none-any.whl (17 kB)
# Downloading array_api_compat-1.14.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 8.8 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading zarr-3.1.6-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 35.7 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 150.7 MB/s eta 0:00:00
# Installing collected packages: texttable, session-info2, numcodecs, legacy-api-wrap, igraph, fast-array-utils, donfig, colorlog, array-api-compat, zarr, pandas, leidenalg, torch_geometric, optuna, GEOparse, anndata, scanpy
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed GEOparse-2.0.4 anndata-0.12.10 array-api-compat-1.14.0 colorlog-6.10.1 donfig-0.8.1.post1 fast-array-utils-1.4.1 igraph-1.0.0 legacy-api-wrap-1.5 leidenalg-0.11.0 numcodecs-0.16.5 optuna-4.8.0 pandas-2.3.3 scanpy-1.12.1 session-info2-0.4.1 texttable-1.7.0 torch_geometric-2.7.0 zarr-3.1.6

# %%
import leidenalg

# %%
# !export TF_CPP_MIN_LOG_LEVEL=2
# !export TF_ENABLE_ONEDNN_OPTS=0

# %%
# !python /content/CellTypeClassification/1_download.py
# Out:
# 2026-04-20 00:03:59.918415: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 00:03:59.926942: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776643439.936497    5936 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776643439.939708    5936 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776643439.947919    5936 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776643439.947934    5936 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776643439.947935    5936 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776643439.947937    5936 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 00:03:59.950371: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [done] matrix.csv
# [done] metadata.csv
# [done] smartseq_meta.csv
# [done] smartseq_data.csv
# downloading: 100% 12.2G/12.2G [00:36<00:00, 360MB/s]
# Metadata: 74,501 cells, 12 classes
# Caching data/10x/matrix.csv -> data/10x/matrix.npy (first run only)
# Expression matrix: (74501, 50281)
# Saved splits to data/10x
# Metadata: 46,086 cells, 12 classes
# Caching data/smartseq/smartseq_data.csv -> data/smartseq/smartseq_data.npy
# (first run only)
# Expression matrix: (46086, 50281)
# Saved splits to data/smartseq
# Setting up hPancreas (TOSICA benchmark)
# Downloading demo_train.h5ad.dl ...
# demo_train.h5ad.dl: 100% 128M/128M [00:01<00:00, 107MB/s]
# [done] demo_train.h5ad.dl
# Downloading demo_test.h5ad.dl ...
# demo_test.h5ad.dl: 100% 51.1M/51.1M [00:00<00:00, 86.8MB/s]
# [done] demo_test.h5ad.dl
#   train: 10,600 cells, 13 types
#   test:  4,218 cells, 11 types
# Saved data/hPancreas: train=9,540  val=1,060  test=4,218  classes=14
# genes=3,000
# Setting up mPancreas (GSE132188)
# Downloading mPancreas.h5ad.dl ...
# mPancreas.h5ad.dl: 100% 334M/334M [00:12<00:00, 27.0MB/s]
# [done] mPancreas.h5ad.dl
# /usr/local/lib/python3.12/dist-packages/anndata/_io/h5ad.py:267: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   return AnnData(**{
# /usr/local/lib/python3.12/dist-packages/anndata/_io/h5ad.py:267: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   return AnnData(**{
# Saved data/mPancreas: train=22,918  val=2,547  test=10,886  classes=21
# genes=17,327
# Setting up mAtlas (GSE132042)
# Downloading mAtlas.h5ad.dl ...
# mAtlas.h5ad.dl: 100% 4.80G/4.80G [01:01<00:00, 78.0MB/s]
# [done] mAtlas.h5ad.dl
# /usr/local/lib/python3.12/dist-packages/anndata/_io/h5ad.py:267: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   return AnnData(**{
# /usr/local/lib/python3.12/dist-packages/anndata/_io/h5ad.py:267: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   return AnnData(**{
# Saved data/mAtlas: train=30,624  val=3,403  test=76,797  classes=120
# genes=22,966

# %%
# !python /content/CellTypeClassification/validate_datasets.py
# Out:
# ============================================================
# hPancreas: 14 classes, train+val=10,600, test=4,218
# ============================================================
#   Acinar                               train:   1144 ✓                test:    209 ✓
#   Alpha                                train:   3136 ✓                test:   2011 ✓
#   Beta                                 train:   2966 ✓                test:   1006 ✓
#   Delta                                train:    793 ✓                test:    188 ✓
#   Ductal                               train:   1290 ✓                test:    414 ✓
#   Endothelial                          train:    273 ✓                test:     16 ✓
#   Epsilon                              train:     21 ✓                test:      7 ✓
#   MHC class II                         train:      0 ✓                test:      5 ✓
#   Macrophage                           train:     52 ✓                test:      0 ✓
#   Mast                                 train:     25 ✓                test:      7 ✓
#   PP                                   train:    356 ✓                test:    282 ✓
#   PSC                                  train:    524 ✓                test:     73 ✓
#   Schwann                              train:     13 ✓                test:      0 ✓
#   T_cell                               train:      7 ✓                test:      0 ✓
#   TOTAL                                train:  10600 ✓            test:   4218 ✓
#
# ============================================================
# mPancreas: 21 classes, train+val=25,465, test=10,886
# ============================================================
#   Alpha                                train:    947 ✓                test:    481 ✓
#   Beta                                 train:    646 ✓                test:    591 ✓
#   Delta                                train:     33 ✓                test:     70 ✓
#   Ductal                               train:   3769 ✓                test:    499 ✓
#   Epsilon                              train:     89 ✓                test:    142 ✓
#   Fev+ Alpha                           train:    339 ✓                test:      6 ✓
#   Fev+ Beta                            train:    902 ✓                test:    457 ✓
#   Fev+ Delta                           train:     59 ✓                test:     51 ✓
#   Fev+ Epsilon                         train:     66 ✓                test:     46 ✓
#   Fev+ Pyy                             train:    100 ✓                test:     32 ✓
#   Mat. Acinar                          train:    108 ✓                test:   6959 ✓
#   Multipotent                          train:   1224 ✓                test:      1 ✓
#   Ngn3 High early                      train:    771 ✓                test:      0 ✓
#   Ngn3 High late                       train:   1090 ✓                test:    642 ✓
#   Ngn3 low EP                          train:   2354 ✓                test:    262 ✓
#   Prlf. Acinar                         train:   3194 ✓                test:    171 ✓
#   Prlf. Ductal                         train:   1890 ✓                test:    417 ✓
#   Prlf. Tip                            train:   2284 ✓                test:      0 ✓
#   Prlf. Trunk                          train:   1168 ✓                test:     37 ✓
#   Tip                                  train:   3815 ✓                test:      6 ✓
#   Trunk                                train:    617 ✓                test:     16 ✓
#   TOTAL                                train:  25465 ✓            test:  10886 ✓
#
# ============================================================
# mAtlas: 120 classes, train+val=34,027, test=76,797
# ============================================================
#   train+val total: 34,027 (expected 34,027) ✓
#   test total:      76,797 (expected 76,797) ✓
#   classes: ['B cell', 'Bergmann glial cell', 'Brush cell of epithelium proper of large intestine', 'CD4-positive, alpha-beta T cell', 'CD8-positive, alpha-beta T cell']...
#
# ============================================================
# SUMMARY
# ============================================================
#   hPancreas     MATCH
#   mPancreas     MATCH
#   mAtlas        MATCH

# %%
# !python /content/CellTypeClassification/2_smartseq_create_npyfile.py & python /content/CellTypeClassification/2_10x_create_npyfile.py
# Out:
# python3: can't open file '/content/CellTypeClassification/2_10x_create_npyfile.py': [Errno 2] No such file or directory
# python3: can't open file '/content/CellTypeClassification/2_smartseq_create_npyfile.py': [Errno 2] No such file or directory

# %%
# !python /content/CellTypeClassification/2_visualize.py
# Out:
# 2026-04-20 00:13:29.612255: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 00:13:29.621050: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776644009.630811    8655 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776644009.634086    8655 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776644009.642540    8655 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776644009.642554    8655 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776644009.642556    8655 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776644009.642574    8655 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 00:13:29.645036: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ╭──── Dataset ─────╮
# │ 10X  ·  data/10x │
# ╰──────────────────╯
# Figure(1200x500)
# Saved figures/10x_class_distribution.png
# Running PCA on training set...
# Figure(1400x500)
# Saved figures/10x_pca.png
#   Subsampled to 6,000 cells for UMAP speed.
# UMAP(min_dist=0.3, n_jobs=48, n_neighbors=30, verbose=True)
# Mon Apr 20 00:13:54 2026 Construct fuzzy simplicial set
# Mon Apr 20 00:13:54 2026 Finding Nearest Neighbors
# Mon Apr 20 00:13:54 2026 Building RP forest with 9 trees
# Mon Apr 20 00:13:55 2026 NN descent for 13 iterations
# 	 1  /  13
# 	 2  /  13
# 	Stopping threshold met -- exiting after 2 iterations
# Mon Apr 20 00:14:01 2026 Finished Nearest Neighbor Search
# Mon Apr 20 00:14:03 2026 Construct embedding
# Epochs completed:   0% 0/500 [00:00<?, ?it/s]	completed  0  /  500 epochs
# Epochs completed:   0% 1/500 [00:00<06:27,  1.29it/s]	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# Epochs completed:  29% 144/500 [00:00<00:01, 223.27it/s]	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# Epochs completed:  48% 241/500 [00:00<00:00, 358.73it/s]	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# Epochs completed:  66% 331/500 [00:01<00:00, 463.84it/s]	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# Epochs completed:  88% 438/500 [00:01<00:00, 599.75it/s]	completed  450  /  500 epochs
# Epochs completed: 100% 500/500 [00:01<00:00, 402.66it/s]
# Mon Apr 20 00:14:05 2026 Finished embedding
# Figure(1000x800)
# Saved figures/10x_umap.png
# /content/CellTypeClassification/allen_brain/cell_data/cell_preprocess.py:33: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:213.)
#   X_t = torch.as_tensor(X_val_filtered, dtype=torch.float32)
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# Figure(1400x800)
# Saved figures/10x_heatmap.png
# Plotting violin plots for top 6 most variable genes...
# Figure(1500x800)
# Saved figures/10x_violin.png
# Computing CV^2 statistics for 50,281 genes ...
#   Fitting LOWESS trend ...
# Figure(1600x600)
#   Top 10 HVGs (select_hvg): ERBB4, KCNIP4, RALYL, NRG1, DPP10, LINGO2, GRIK1,
# ROBO2, SGCZ, NXPH1
# Saved figures/10x_cv2.png
# ╭───────── Dataset ──────────╮
# │ SMARTSEQ  ·  data/smartseq │
# ╰────────────────────────────╯
# Figure(1200x500)
# Saved figures/smartseq_class_distribution.png
# Running PCA on training set...
# Figure(1400x500)
# Saved figures/smartseq_pca.png
#   Subsampled to 6,000 cells for UMAP speed.
# UMAP(min_dist=0.3, n_jobs=48, n_neighbors=30, verbose=True)
# Mon Apr 20 00:14:39 2026 Construct fuzzy simplicial set
# Mon Apr 20 00:14:39 2026 Finding Nearest Neighbors
# Mon Apr 20 00:14:39 2026 Building RP forest with 9 trees
# Mon Apr 20 00:14:39 2026 NN descent for 13 iterations
# 	 1  /  13
# 	 2  /  13
# 	Stopping threshold met -- exiting after 2 iterations
# Mon Apr 20 00:14:39 2026 Finished Nearest Neighbor Search
# Mon Apr 20 00:14:39 2026 Construct embedding
# Epochs completed:   0% 0/500 [00:00<?, ?it/s]	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# Epochs completed:  11% 55/500 [00:00<00:00, 548.00it/s]	completed  100  /  500 epochs
# Epochs completed:  29% 145/500 [00:00<00:00, 751.31it/s]	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# Epochs completed:  53% 265/500 [00:00<00:00, 952.76it/s]	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# Epochs completed:  77% 386/500 [00:00<00:00, 1051.74it/s]	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Epochs completed: 100% 500/500 [00:00<00:00, 1002.22it/s]
# Mon Apr 20 00:14:40 2026 Finished embedding
# Figure(1000x800)
# Saved figures/smartseq_umap.png
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# Figure(1400x800)
# Saved figures/smartseq_heatmap.png
# Plotting violin plots for top 6 most variable genes...
# Figure(1500x800)
# Saved figures/smartseq_violin.png
# Computing CV^2 statistics for 50,281 genes ...
#   Fitting LOWESS trend ...
# Figure(1600x600)
#   Top 10 HVGs (select_hvg): KCNIP4, ERBB4, ROBO2, DPP10, CNTN5, LRRTM4, RALYL,
# LINGO2, NRG1, ADARB2
# Saved figures/smartseq_cv2.png
# ╭────────── Dataset ───────────╮
# │ HPANCREAS  ·  data/hPancreas │
# ╰──────────────────────────────╯
# Figure(1200x500)
# Saved figures/hPancreas_class_distribution.png
# Running PCA on training set...
# Figure(1400x500)
# Saved figures/hPancreas_pca.png
#   Subsampled to 6,000 cells for UMAP speed.
# UMAP(min_dist=0.3, n_jobs=48, n_neighbors=30, verbose=True)
# Mon Apr 20 00:15:10 2026 Construct fuzzy simplicial set
# Mon Apr 20 00:15:10 2026 Finding Nearest Neighbors
# Mon Apr 20 00:15:10 2026 Building RP forest with 9 trees
# Mon Apr 20 00:15:10 2026 NN descent for 13 iterations
# 	 1  /  13
# 	 2  /  13
# 	Stopping threshold met -- exiting after 2 iterations
# Mon Apr 20 00:15:10 2026 Finished Nearest Neighbor Search
# Mon Apr 20 00:15:10 2026 Construct embedding
# Epochs completed:   0% 0/500 [00:00<?, ?it/s]	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# Epochs completed:  12% 59/500 [00:00<00:00, 583.75it/s]	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# Epochs completed:  32% 160/500 [00:00<00:00, 829.37it/s]	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# Epochs completed:  55% 275/500 [00:00<00:00, 974.18it/s]	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# Epochs completed:  80% 400/500 [00:00<00:00, 1080.77it/s]	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Epochs completed: 100% 500/500 [00:00<00:00, 1053.73it/s]
# Mon Apr 20 00:15:11 2026 Finished embedding
# Figure(1000x800)
# Saved figures/hPancreas_umap.png
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# Figure(1400x800)
# Saved figures/hPancreas_heatmap.png
# Plotting violin plots for top 6 most variable genes...
# Figure(1500x800)
# Saved figures/hPancreas_violin.png
# Computing CV^2 statistics for 3,000 genes ...
#   Fitting LOWESS trend ...
# Figure(1600x600)
#   Top 10 HVGs (select_hvg): IAPP, PPP1R1A, SERPINA1, VGF, SLC30A8, TM4SF4, GPX3,
# CHGB, FXYD2, UCHL1
# Saved figures/hPancreas_cv2.png
# ╭────────── Dataset ───────────╮
# │ MPANCREAS  ·  data/mPancreas │
# ╰──────────────────────────────╯
# Figure(1200x500)
# Saved figures/mPancreas_class_distribution.png
# Running PCA on training set...
# Traceback (most recent call last):
#   File "/content/CellTypeClassification/2_visualize.py", line 91, in <module>
#     main()
#   File "/content/CellTypeClassification/2_visualize.py", line 86, in main
#     run_visualizations(data_dir, tag)
#   File "/content/CellTypeClassification/2_visualize.py", line 52, in run_visualizations
#     pca, X_pca = vis.plot_pca(
#                  ^^^^^^^^^^^^^
#   File "/content/CellTypeClassification/allen_brain/cell_data/cell_vis.py", line 107, in plot_pca
#     X = X - X.mean(axis=0)
#             ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py", line 115, in _mean
#     rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py", line 86, in _count_reduce_items
#     items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy.exceptions.AxisError: axis 0 is out of bounds for array of dimension 0

# %%
# !python /content/CellTypeClassification/3_MLP.py
# Out:
# 2026-04-20 01:01:49.252549: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 01:01:49.261524: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776646909.271430   25482 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776646909.274793   25482 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776646909.283361   25482 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776646909.283377   25482 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776646909.283379   25482 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776646909.283380   25482 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 01:01:49.285881: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Selecting top 10000 HVGs by variance on train split...
# train: 72093 cells (balanced), 21 classes, 10000 genes
# val:   2547 cells
# Model parameters: 2,612,533
#  Epoch | Train Loss | Train Acc |  Val Loss |  Val Acc | LR
# ------------------------------------------------------------------------
#      1 |     3.0401 |   0.0623 |    3.0325 |   0.0561 | 9.94e-03 *
#      2 |     3.0064 |   0.1431 |    2.9748 |   0.2426 | 9.76e-03 *
#      3 |     2.9338 |   0.2228 |    2.8936 |   0.2568 | 9.46e-03 *
#      4 |     2.7969 |   0.2705 |    2.7391 |   0.1810 | 9.05e-03 *
#      5 |     2.5546 |   0.2964 |    2.4800 |   0.1464 | 8.55e-03 *
#      6 |     2.2341 |   0.3444 |    2.1924 |   0.3632 | 7.96e-03 *
#      7 |     1.9554 |   0.4038 |    1.9609 |   0.4515 | 7.30e-03 *
#      8 |     1.7321 |   0.4402 |    1.7773 |   0.5128 | 6.58e-03 *
#      9 |     1.5369 |   0.4872 |    1.5892 |   0.5465 | 5.82e-03 *
#     10 |     1.3691 |   0.5371 |    1.4346 |   0.5768 | 5.05e-03 *
#     11 |     1.2398 |   0.5740 |    1.3284 |   0.5952 | 4.28e-03 *
#     12 |     1.1380 |   0.6060 |    1.2429 |   0.6105 | 3.52e-03 *
#     13 |     1.0666 |   0.6282 |    1.1849 |   0.6278 | 2.80e-03 *
#     14 |     1.0134 |   0.6481 |    1.1549 |   0.6305 | 2.14e-03 *
#     15 |     0.9760 |   0.6568 |    1.1248 |   0.6368 | 1.55e-03 *
#     16 |     0.9521 |   0.6650 |    1.1107 |   0.6404 | 1.05e-03 *
#     17 |     0.9312 |   0.6743 |    1.1013 |   0.6415 | 6.40e-04 *
#     18 |     0.9252 |   0.6743 |    1.0916 |   0.6435 | 3.42e-04 *
#     19 |     0.9134 |   0.6813 |    1.0877 |   0.6435 | 1.61e-04 *
#     20 |     0.9114 |   0.6803 |    1.0870 |   0.6431 | 1.00e-04 *
# Applied HVG selection: 10000 genes
# Model parameters: 2,612,533
# Loaded checkpoint:
# runs/CellTypeMLP/CellTypeMLP_hvg10000_bs8192_epochs20_lr0.01_wd1e-06_20260420_01
# 0156/best_model.pt
# ╭────────────────────╮
# │ EVALUATION RESULTS │
# ╰────────────────────╯
#                  precision    recall  f1-score   support
#
#           Alpha       0.82      0.88      0.85       481
#            Beta       0.89      0.89      0.89       591
#           Delta       0.70      0.97      0.81        70
#          Ductal       0.64      0.77      0.70       499
#         Epsilon       0.95      0.64      0.76       142
#      Fev+ Alpha       0.05      1.00      0.10         6
#       Fev+ Beta       0.85      0.58      0.69       457
#      Fev+ Delta       0.85      0.67      0.75        51
#    Fev+ Epsilon       0.57      0.93      0.71        46
#        Fev+ Pyy       0.32      0.97      0.48        32
#     Mat. Acinar       0.99      0.75      0.85      6959
#     Multipotent       0.04      1.00      0.08         1
# Ngn3 High early       0.00      0.00      0.00         0
#  Ngn3 High late       0.97      0.88      0.92       642
#     Ngn3 low EP       0.58      0.37      0.46       262
#    Prlf. Acinar       0.06      0.65      0.11       171
#    Prlf. Ductal       0.83      0.46      0.59       417
#       Prlf. Tip       0.00      0.00      0.00         0
#     Prlf. Trunk       0.70      0.81      0.75        37
#             Tip       0.00      0.00      0.00         6
#           Trunk       0.14      0.69      0.23        16
#
#        accuracy                           0.74     10886
#       macro avg       0.52      0.66      0.51     10886
#    weighted avg       0.91      0.74      0.81     10886
#
# Accuracy: 0.7446
# F1 (macro): 0.5115  F1 (weighted): 0.8088
# Precision (macro): 0.5218  Precision (weighted): 0.9138
# Recall (macro): 0.6625  Recall (weighted): 0.7446
# Saved confusion matrix to
# runs/CellTypeMLP/CellTypeMLP_hvg10000_bs8192_epochs20_lr0.01_wd1e-06_20260420_01
# 0156/confusion_matrix.png
# Results for MLP written to results.csv

# %%
# !python /content/CellTypeClassification/3_CNN.py
# Out:
# 2026-04-20 01:02:36.219539: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 01:02:36.228550: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776646956.238505   25878 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776646956.241868   25878 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776646956.250508   25878 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776646956.250524   25878 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776646956.250526   25878 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776646956.250527   25878 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 01:02:36.253038: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Selecting top 10000 HVGs by variance on train split...
# train: 72093 cells (balanced), 21 classes, 10000 genes
# val:   2547 cells
# Model parameters: 57,733
#  Epoch | Train Loss | Train Acc |  Val Loss |  Val Acc | LR
# ------------------------------------------------------------------------
#      1 |     3.2203 |   0.0490 |    3.2176 |   0.0173 | 9.94e-04 *
#      2 |     3.2004 |   0.0495 |    3.1778 |   0.0259 | 9.76e-04 *
#      3 |     3.1664 |   0.0512 |    3.1364 |   0.0424 | 9.46e-04 *
#      4 |     3.1317 |   0.0538 |    3.0996 |   0.1017 | 9.05e-04 *
#      5 |     3.1022 |   0.0568 |    3.0713 |   0.1178 | 8.55e-04 *
#      6 |     3.0817 |   0.0585 |    3.0518 |   0.1225 | 7.96e-04 *
#      7 |     3.0680 |   0.0579 |    3.0376 |   0.1178 | 7.30e-04 *
#      8 |     3.0570 |   0.0643 |    3.0287 |   0.1115 | 6.58e-04 *
#      9 |     3.0497 |   0.0634 |    3.0226 |   0.1001 | 5.82e-04 *
#     10 |     3.0466 |   0.0640 |    3.0185 |   0.0844 | 5.05e-04 *
#     11 |     3.0421 |   0.0660 |    3.0161 |   0.0730 | 4.28e-04 *
#     12 |     3.0406 |   0.0657 |    3.0144 |   0.0695 | 3.52e-04 *
#     13 |     3.0367 |   0.0673 |    3.0127 |   0.0722 | 2.80e-04 *
#     14 |     3.0347 |   0.0691 |    3.0121 |   0.0707 | 2.14e-04 *
#     15 |     3.0332 |   0.0682 |    3.0117 |   0.0742 | 1.55e-04 *
#     16 |     3.0349 |   0.0686 |    3.0103 |   0.0789 | 1.05e-04 *
#     17 |     3.0320 |   0.0699 |    3.0094 |   0.0824 | 6.40e-05 *
#     18 |     3.0314 |   0.0702 |    3.0095 |   0.0828 | 3.42e-05
#     19 |     3.0328 |   0.0696 |    3.0096 |   0.0828 | 1.61e-05
#     20 |     3.0326 |   0.0703 |    3.0095 |   0.0828 | 1.00e-05
# Applied HVG selection: 10000 genes
# Model parameters: 57,733
# Loaded checkpoint:
# runs/CellTypeCNN/CellTypeCNN_hvg10000_bs16384_epochs20_lr0.0003_wd1e-06_20260420
# _010243/best_model.pt
# ╭────────────────────╮
# │ EVALUATION RESULTS │
# ╰────────────────────╯
#                  precision    recall  f1-score   support
#
#           Alpha       0.50      0.02      0.04       481
#            Beta       0.21      0.19      0.20       591
#           Delta       0.01      0.16      0.02        70
#          Ductal       0.15      0.03      0.05       499
#         Epsilon       0.02      0.01      0.01       142
#      Fev+ Alpha       0.01      0.17      0.03         6
#       Fev+ Beta       0.05      0.04      0.05       457
#      Fev+ Delta       0.02      0.57      0.03        51
#    Fev+ Epsilon       0.00      0.00      0.00        46
#        Fev+ Pyy       0.00      0.00      0.00        32
#     Mat. Acinar       0.92      0.30      0.45      6959
#     Multipotent       0.00      0.00      0.00         1
# Ngn3 High early       0.00      0.00      0.00         0
#  Ngn3 High late       0.13      0.10      0.11       642
#     Ngn3 low EP       0.10      0.03      0.05       262
#    Prlf. Acinar       0.02      0.27      0.03       171
#    Prlf. Ductal       0.14      0.00      0.00       417
#       Prlf. Tip       0.00      0.00      0.00         0
#     Prlf. Trunk       0.01      0.03      0.02        37
#             Tip       0.00      0.00      0.00         6
#           Trunk       0.01      0.44      0.03        16
#
#        accuracy                           0.22     10886
#       macro avg       0.11      0.11      0.05     10886
#    weighted avg       0.65      0.22      0.31     10886
#
# Accuracy: 0.2185
# F1 (macro): 0.0526  F1 (weighted): 0.3113
# Precision (macro): 0.1100  Precision (weighted): 0.6474
# Recall (macro): 0.1118  Recall (weighted): 0.2185
# Saved confusion matrix to
# runs/CellTypeCNN/CellTypeCNN_hvg10000_bs16384_epochs20_lr0.0003_wd1e-06_20260420
# _010243/confusion_matrix.png
# Results for CNN written to results.csv

# %%
# !python /content/CellTypeClassification/3_GNN.py
# Out:
# 2026-04-20 01:37:03.723777: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 01:37:03.732661: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776649023.742464   36608 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776649023.745779   36608 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776649023.754326   36608 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776649023.754342   36608 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776649023.754343   36608 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776649023.754345   36608 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 01:37:03.756808: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GNN: selected top 10000 HVGs (10000 genes)
# Building k=10 cosine-NN graph on 85,526 cells...
# Graph: 85,526 nodes, 1,527,577 edges, avg deg 17.9
# Model parameters: 2,893,077
#  Epoch | Train Loss | Train Acc |  Val Loss |  Val Acc | LR
# ------------------------------------------------------------------------
#      1 |     3.1637 |   0.0410 |    3.0327 |   0.0687 | 9.94e-04 *
#      2 |     3.0966 |   0.0540 |    2.9472 |   0.0931 | 9.76e-04 *
#      3 |     3.0389 |   0.0720 |    2.9023 |   0.0942 | 9.46e-04 *
#      4 |     2.9941 |   0.0890 |    2.8676 |   0.1001 | 9.05e-04 *
#      5 |     2.9530 |   0.1095 |    2.8306 |   0.1355 | 8.55e-04 *
#      6 |     2.9010 |   0.1335 |    2.7963 |   0.1661 | 7.96e-04 *
#      7 |     2.8451 |   0.1561 |    2.7690 |   0.1692 | 7.30e-04 *
#      8 |     2.8025 |   0.1660 |    2.7410 |   0.1814 | 6.58e-04 *
#      9 |     2.7597 |   0.1774 |    2.7057 |   0.1928 | 5.82e-04 *
#     10 |     2.7193 |   0.1845 |    2.6678 |   0.2073 | 5.05e-04 *
#     11 |     2.6744 |   0.1952 |    2.6329 |   0.1987 | 4.28e-04 *
#     12 |     2.6304 |   0.2070 |    2.6037 |   0.1771 | 3.52e-04 *
#     13 |     2.5958 |   0.2130 |    2.5788 |   0.1684 | 2.80e-04 *
#     14 |     2.5652 |   0.2222 |    2.5575 |   0.1720 | 2.14e-04 *
#     15 |     2.5419 |   0.2293 |    2.5398 |   0.1739 | 1.55e-04 *
#     16 |     2.5176 |   0.2410 |    2.5261 |   0.1802 | 1.05e-04 *
#     17 |     2.5015 |   0.2457 |    2.5164 |   0.1865 | 6.40e-05 *
#     18 |     2.5006 |   0.2422 |    2.5100 |   0.1888 | 3.42e-05 *
#     19 |     2.4925 |   0.2458 |    2.5065 |   0.1908 | 1.61e-05 *
#     20 |     2.4875 |   0.2502 |    2.5048 |   0.1904 | 1.00e-05 *
# Model parameters: 2,893,077
# Loaded checkpoint:
# runs/CellTypeGNN/CellTypeGNN_hvg10000_bs256_epochs20_lr0.0003_wd1e-06_20260420_0
# 13718/best_model.pt
# ╭────────────────────╮
# │ EVALUATION RESULTS │
# ╰────────────────────╯
#                  precision    recall  f1-score   support
#
#           Alpha       0.45      0.19      0.27       481
#            Beta       0.48      0.71      0.57       591
#           Delta       0.00      0.00      0.00        70
#          Ductal       0.45      0.12      0.19       499
#         Epsilon       0.81      0.15      0.25       142
#      Fev+ Alpha       0.01      0.33      0.01         6
#       Fev+ Beta       0.38      0.44      0.40       457
#      Fev+ Delta       0.08      0.06      0.07        51
#    Fev+ Epsilon       0.47      0.15      0.23        46
#        Fev+ Pyy       0.04      0.06      0.05        32
#     Mat. Acinar       1.00      0.26      0.42      6959
#     Multipotent       0.00      0.00      0.00         1
# Ngn3 High early       0.00      0.00      0.00         0
#  Ngn3 High late       0.95      0.49      0.65       642
#     Ngn3 low EP       0.23      0.63      0.33       262
#    Prlf. Acinar       0.00      0.00      0.00       171
#    Prlf. Ductal       0.50      0.01      0.02       417
#       Prlf. Tip       0.00      0.00      0.00         0
#     Prlf. Trunk       0.08      0.03      0.04        37
#             Tip       0.00      0.17      0.01         6
#           Trunk       0.00      0.50      0.00        16
#
#        accuracy                           0.29     10886
#       macro avg       0.28      0.20      0.17     10886
#    weighted avg       0.81      0.29      0.39     10886
#
# Accuracy: 0.2885
# F1 (macro): 0.1675  F1 (weighted): 0.3876
# Precision (macro): 0.2817  Precision (weighted): 0.8124
# Recall (macro): 0.2049  Recall (weighted): 0.2885
# Saved confusion matrix to
# runs/CellTypeGNN/CellTypeGNN_hvg10000_bs256_epochs20_lr0.0003_wd1e-06_20260420_0
# 13718/confusion_matrix.png
# Results for GNN written to results.csv

# %%
# !python /content/CellTypeClassification/3_Transformer.py
# Out:
# 2026-04-20 01:31:11.544967: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 01:31:11.554038: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776648671.564125   34920 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776648671.567538   34920 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776648671.576239   34920 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776648671.576253   34920 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776648671.576255   34920 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776648671.576256   34920 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 01:31:11.578803: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Selecting top 10000 HVGs by variance on train split...
# train: 72093 cells (balanced), 21 classes, 10000 genes
# val:   2547 cells
# Gene sets loaded: 1,214
# Mask: (10000, 300), sparsity 99.29%
# /content/CellTypeClassification/allen_brain/models/CellTypeAttention.py:161: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
# Model parameters: 144,077,829
#  Epoch | Train Loss | Train Acc |  Val Loss |  Val Acc | LR
# ------------------------------------------------------------------------
#      1 |     2.4245 |   0.2128 |    1.9055 |   0.2917 | 9.94e-04 *
#      2 |     1.6490 |   0.4260 |    1.6022 |   0.3981 | 9.76e-04 *
#      3 |     1.3576 |   0.5503 |    1.3562 |   0.5194 | 9.46e-04 *
#      4 |     1.1015 |   0.6647 |    1.1545 |   0.6093 | 9.05e-04 *
#      5 |     0.8899 |   0.7448 |    1.0318 |   0.6608 | 8.55e-04 *
#      6 |     0.7381 |   0.7921 |    0.9520 |   0.6847 | 7.96e-04 *
#      7 |     0.6374 |   0.8236 |    0.8994 |   0.6961 | 7.30e-04 *
#      8 |     0.5637 |   0.8447 |    0.8876 |   0.7020 | 6.58e-04 *
#      9 |     0.5082 |   0.8610 |    0.8703 |   0.7095 | 5.82e-04 *
#     10 |     0.4641 |   0.8764 |    0.8431 |   0.7161 | 5.05e-04 *
#     11 |     0.4298 |   0.8869 |    0.8432 |   0.7142 | 4.28e-04
#     12 |     0.4016 |   0.8947 |    0.8338 |   0.7197 | 3.52e-04 *
#     13 |     0.3797 |   0.9019 |    0.8417 |   0.7154 | 2.80e-04
#     14 |     0.3635 |   0.9062 |    0.8316 |   0.7228 | 2.14e-04 *
#     15 |     0.3503 |   0.9107 |    0.8269 |   0.7193 | 1.55e-04 *
#     16 |     0.3397 |   0.9145 |    0.8386 |   0.7208 | 1.05e-04
#     17 |     0.3319 |   0.9166 |    0.8259 |   0.7240 | 6.40e-05 *
#     18 |     0.3273 |   0.9202 |    0.8338 |   0.7205 | 3.42e-05
#     19 |     0.3239 |   0.9200 |    0.8365 |   0.7193 | 1.61e-05
#     20 |     0.3228 |   0.9201 |    0.8334 |   0.7224 | 1.00e-05
# Applied HVG selection: 10000 genes
# Model parameters: 144,077,829
# Loaded checkpoint:
# runs/CellTypeTOSICA/CellTypeTOSICA_hvg10000_bs64_epochs20_lr0.0003_wd1e-06_20260
# 420_013119/best_model.pt
# ╭────────────────────╮
# │ EVALUATION RESULTS │
# ╰────────────────────╯
#                  precision    recall  f1-score   support
#
#           Alpha       0.71      0.83      0.76       481
#            Beta       0.90      0.73      0.81       591
#           Delta       0.68      0.49      0.57        70
#          Ductal       0.78      0.33      0.46       499
#         Epsilon       0.81      0.50      0.62       142
#      Fev+ Alpha       0.02      0.33      0.03         6
#       Fev+ Beta       0.63      0.76      0.69       457
#      Fev+ Delta       0.50      0.14      0.22        51
#    Fev+ Epsilon       0.37      0.50      0.43        46
#        Fev+ Pyy       0.26      0.72      0.38        32
#     Mat. Acinar       0.99      0.86      0.92      6959
#     Multipotent       0.00      0.00      0.00         1
# Ngn3 High early       0.00      0.00      0.00         0
#  Ngn3 High late       0.89      0.75      0.81       642
#     Ngn3 low EP       0.29      0.32      0.31       262
#    Prlf. Acinar       0.12      0.76      0.21       171
#    Prlf. Ductal       0.68      0.79      0.73       417
#       Prlf. Tip       0.00      0.00      0.00         0
#     Prlf. Trunk       0.55      0.78      0.64        37
#             Tip       0.00      0.00      0.00         6
#           Trunk       0.15      0.44      0.23        16
#
#        accuracy                           0.79     10886
#       macro avg       0.44      0.48      0.42     10886
#    weighted avg       0.88      0.79      0.82     10886
#
# Accuracy: 0.7884
# F1 (macro): 0.4193  F1 (weighted): 0.8227
# Precision (macro): 0.4437  Precision (weighted): 0.8845
# Recall (macro): 0.4778  Recall (weighted): 0.7884
# Saved confusion matrix to
# runs/CellTypeTOSICA/CellTypeTOSICA_hvg10000_bs64_epochs20_lr0.0003_wd1e-06_20260
# 420_013119/confusion_matrix.png
# Results for Transformer written to results.csv

# %%
# !python /content/CellTypeClassification/3_TOSICA.py
# Out:
# 2026-04-20 01:40:17.122039: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 01:40:17.130916: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776649217.140725   37618 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776649217.144044   37618 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776649217.152591   37618 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776649217.152605   37618 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776649217.152606   37618 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776649217.152608   37618 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 01:40:17.155082: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# cuda:0
# Balancing populations...
# /content/CellTypeClassification/allen_brain/TOSICA/train.py:55: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   ct_counts = pd.value_counts(data[:,-1])
# Mask loaded!
# Model builded!
# [train epoch 0] loss: 3.047, acc: 0.047: 100% 788/788 [00:15<00:00, 51.37it/s]
# [valid epoch 0] loss: 3.046, acc: 0.066: 100% 337/337 [00:03<00:00, 111.88it/s]
# [train epoch 1] loss: 3.004, acc: 0.057: 100% 788/788 [00:14<00:00, 52.93it/s]
# [valid epoch 1] loss: 2.489, acc: 0.096: 100% 337/337 [00:02<00:00, 113.79it/s]
# [train epoch 2] loss: 2.333, acc: 0.143: 100% 788/788 [00:14<00:00, 52.86it/s]
# [valid epoch 2] loss: 2.046, acc: 0.211: 100% 337/337 [00:02<00:00, 113.46it/s]
# [train epoch 3] loss: 2.032, acc: 0.213: 100% 788/788 [00:14<00:00, 52.82it/s]
# [valid epoch 3] loss: 1.786, acc: 0.305: 100% 337/337 [00:02<00:00, 114.34it/s]
# [train epoch 4] loss: 1.708, acc: 0.330: 100% 788/788 [00:14<00:00, 53.12it/s]
# [valid epoch 4] loss: 1.544, acc: 0.416: 100% 337/337 [00:02<00:00, 115.47it/s]
# [train epoch 5] loss: 1.544, acc: 0.405: 100% 788/788 [00:14<00:00, 53.30it/s]
# [valid epoch 5] loss: 1.384, acc: 0.494: 100% 337/337 [00:02<00:00, 113.11it/s]
# [train epoch 6] loss: 1.432, acc: 0.459: 100% 788/788 [00:14<00:00, 52.78it/s]
# [valid epoch 6] loss: 1.299, acc: 0.492: 100% 337/337 [00:02<00:00, 113.13it/s]
# [train epoch 7] loss: 1.349, acc: 0.494: 100% 788/788 [00:14<00:00, 53.07it/s]
# [valid epoch 7] loss: 1.298, acc: 0.478: 100% 337/337 [00:02<00:00, 113.27it/s]
# [train epoch 8] loss: 1.300, acc: 0.515: 100% 788/788 [00:14<00:00, 53.07it/s]
# [valid epoch 8] loss: 1.173, acc: 0.606: 100% 337/337 [00:02<00:00, 114.35it/s]
# [train epoch 9] loss: 1.254, acc: 0.533: 100% 788/788 [00:14<00:00, 53.01it/s]
# [valid epoch 9] loss: 1.108, acc: 0.653: 100% 337/337 [00:02<00:00, 114.25it/s]
# [train epoch 10] loss: 1.209, acc: 0.556: 100% 788/788 [00:14<00:00, 53.18it/s]
# [valid epoch 10] loss: 1.106, acc: 0.652: 100% 337/337 [00:02<00:00, 113.62it/s]
# [train epoch 11] loss: 1.164, acc: 0.586: 100% 788/788 [00:14<00:00, 52.67it/s]
# [valid epoch 11] loss: 1.039, acc: 0.677: 100% 337/337 [00:02<00:00, 113.16it/s]
# [train epoch 12] loss: 1.135, acc: 0.602: 100% 788/788 [00:14<00:00, 52.65it/s]
# [valid epoch 12] loss: 1.011, acc: 0.715: 100% 337/337 [00:02<00:00, 112.56it/s]
# [train epoch 13] loss: 1.110, acc: 0.613: 100% 788/788 [00:14<00:00, 53.12it/s]
# [valid epoch 13] loss: 0.991, acc: 0.720: 100% 337/337 [00:02<00:00, 114.31it/s]
# [train epoch 14] loss: 1.085, acc: 0.632: 100% 788/788 [00:14<00:00, 53.20it/s]
# [valid epoch 14] loss: 0.989, acc: 0.709: 100% 337/337 [00:02<00:00, 117.05it/s]
# [train epoch 15] loss: 1.069, acc: 0.643: 100% 788/788 [00:14<00:00, 52.93it/s]
# [valid epoch 15] loss: 0.959, acc: 0.742: 100% 337/337 [00:02<00:00, 113.24it/s]
# [train epoch 16] loss: 1.054, acc: 0.656: 100% 788/788 [00:14<00:00, 52.54it/s]
# [valid epoch 16] loss: 0.945, acc: 0.756: 100% 337/337 [00:02<00:00, 113.45it/s]
# [train epoch 17] loss: 1.045, acc: 0.662: 100% 788/788 [00:14<00:00, 52.89it/s]
# [valid epoch 17] loss: 0.949, acc: 0.754: 100% 337/337 [00:02<00:00, 114.42it/s]
# [train epoch 18] loss: 1.039, acc: 0.666: 100% 788/788 [00:14<00:00, 52.81it/s]
# [valid epoch 18] loss: 0.941, acc: 0.759: 100% 337/337 [00:02<00:00, 114.37it/s]
# [train epoch 19] loss: 1.034, acc: 0.671: 100% 788/788 [00:14<00:00, 52.84it/s]
# [valid epoch 19] loss: 0.942, acc: 0.754: 100% 337/337 [00:02<00:00, 113.92it/s]
# Training finished!
# cuda:0
# 0
# 10000
# 10886
# /usr/local/lib/python3.12/dist-packages/anndata/_core/anndata.py:1823: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ╭────────────────────╮
# │ EVALUATION RESULTS │
# ╰────────────────────╯
#                  precision    recall  f1-score   support
#
#           Alpha       0.65      0.79      0.72       481
#            Beta       0.70      0.68      0.69       591
#           Delta       0.06      0.37      0.11        70
#          Ductal       0.59      0.42      0.49       499
#         Epsilon       0.28      0.18      0.22       142
#      Fev+ Alpha       0.02      0.50      0.03         6
#       Fev+ Beta       0.62      0.26      0.37       457
#      Fev+ Delta       0.13      0.25      0.17        51
#    Fev+ Epsilon       0.06      0.33      0.10        46
#        Fev+ Pyy       0.08      0.34      0.12        32
#     Mat. Acinar       0.99      0.91      0.95      6959
#     Multipotent       0.00      0.00      0.00         1
# Ngn3 High early       0.00      0.00      0.00         0
#  Ngn3 High late       1.00      0.47      0.63       642
#     Ngn3 low EP       0.16      0.07      0.10       262
#    Prlf. Acinar       0.28      0.61      0.38       171
#    Prlf. Ductal       0.45      0.30      0.36       417
#       Prlf. Tip       0.00      0.00      0.00         0
#     Prlf. Trunk       0.06      0.24      0.10        37
#             Tip       0.00      0.00      0.00         6
#           Trunk       0.02      0.19      0.03        16
#
#        accuracy                           0.74     10886
#       macro avg       0.29      0.33      0.27     10886
#    weighted avg       0.84      0.74      0.78     10886
#
# Accuracy: 0.7438
# F1 (macro): 0.2655  F1 (weighted): 0.7787
# Precision (macro): 0.2933  Precision (weighted): 0.8432
# Recall (macro): 0.3288  Recall (weighted): 0.7438
# Saved confusion matrix to tosica_run/confusion_matrix.png
# Results for TOSICA written to results.csv

# %%
# !python /content/CellTypeClassification/6_model_comparison.py
# Out:
# 2026-04-20 01:07:32.269845: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 01:07:32.278854: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776647252.288788   28030 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776647252.292148   28030 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776647252.300784   28030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776647252.300798   28030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776647252.300800   28030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776647252.300801   28030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 01:07:32.303316: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ╭──────────────────╮
# │ MODEL COMPARISON │
# ╰──────────────────╯
# Loading MLP...
# Model parameters: 2,612,533
#   MLP: 10886 test samples
# Loading CNN...
# Model parameters: 57,733
#   CNN: 10886 test samples
# Loading Transformer...
# /content/CellTypeClassification/allen_brain/models/CellTypeAttention.py:161: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
# Model parameters: 895,269
#   Transformer: 10886 test samples
# Loading GNN...
# Building k=15 cosine-NN graph on 85,526 cells...
# Graph: 85,526 nodes, 2,316,082 edges, avg deg 27.1
# Model parameters: 4,768,789
# Traceback (most recent call last):
#   File "/content/CellTypeClassification/6_model_comparison.py", line 149, in <module>
#     main()
#   File "/content/CellTypeClassification/6_model_comparison.py", line 129, in main
#     results: dict[str, ModelPredictions] = _collect_all()
#                                            ^^^^^^^^^^^^^^
#   File "/content/CellTypeClassification/6_model_comparison.py", line 113, in _collect_all
#     r: ModelPredictions | None = _load_and_predict(cls_name, squeeze, is_graph)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/CellTypeClassification/6_model_comparison.py", line 61, in _load_and_predict
#     model.load_state_dict(torch.load(ckpt, map_location=T.DEVICE, weights_only=True))
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2635, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for CellTypeGNN:
# 	size mismatch for encoder.0.weight: copying a param with shape torch.Size([256, 10000]) from checkpoint, the shape in current model is torch.Size([256, 17327]).

# %%
# !python /content/CellTypeClassification/7_interpretability.py
# Out:
# 2026-04-20 01:08:01.595791: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 01:08:01.604738: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776647281.614768   28342 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776647281.618128   28342 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776647281.626752   28342 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776647281.626765   28342 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776647281.626767   28342 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776647281.626768   28342 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-20 01:08:01.629247: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ╭───────────────────────────╮
# │ INTERPRETABILITY ANALYSIS │
# ╰───────────────────────────╯
# ╭──────────────────────────╮
# │ TOSICA Pathway Attention │
# ╰──────────────────────────╯
# Gene sets loaded: 1,649
# Mask: (17327, 1), sparsity 99.96%
# /content/CellTypeClassification/allen_brain/models/CellTypeAttention.py:161: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
# Model parameters: 895,269
# Saved tosica_pathway_attention_heatmap.png
# Saved tosica_top_pathways_per_class.png
# ╭────────────────────╮
# │ GNN Embedding UMAP │
# ╰────────────────────╯
# Building k=15 cosine-NN graph on 85,526 cells...
# Graph: 85,526 nodes, 2,316,476 edges, avg deg 27.1
# Model parameters: 4,768,789
# Error in interpret_gnn: Error(s) in loading state_dict for CellTypeGNN:
#         size mismatch for encoder.0.weight: copying a param with shape
# torch.Size([256, 10000]) from checkpoint, the shape in current model is
# torch.Size([256, 17327]).
# Traceback (most recent call last):
#   File "/content/CellTypeClassification/7_interpretability.py", line 551, in main
#     fn(SAVE_DIR)
#   File "/content/CellTypeClassification/7_interpretability.py", line 195, in interpret_gnn
#     model.load_state_dict(torch.load(ckpt, map_location=T.DEVICE, weights_only=True))
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2635, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for CellTypeGNN:
# 	size mismatch for encoder.0.weight: copying a param with shape torch.Size([256, 10000]) from checkpoint, the shape in current model is torch.Size([256, 17327]).
# ╭───────────────────╮
# │ MLP Gene Saliency │
# ╰───────────────────╯
# Model parameters: 2,612,533
# Saved mlp_gene_saliency_top20.png
# Saved mlp_saliency_per_class.png
# ╭─────────────────────────────╮
# │ CNN Gene Saliency + Filters │
# ╰─────────────────────────────╯
# Model parameters: 57,733
# Saved cnn_gene_saliency_top20.png
# Saved cnn_saliency_per_class.png
# Saved cnn_stem_filters.png
# ╭─────────────────────────────╮
# │ Cross-Model Gene Importance │
# ╰─────────────────────────────╯
# Model parameters: 2,612,533
# Model parameters: 57,733
# Gene sets loaded: 1,649
# Mask: (17327, 1), sparsity 99.96%
# Saved gene_importance_comparison.png
# ╭───────────────────────────────╮
# │ All figures saved to figures/ │
# ╰───────────────────────────────╯

# %%
# %load_ext tensorboard

# %%
# !watch nvidia-smi
# Out:
# -771740303004622446688404022446688505022294466884:004:0052264456688101022446688

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %tensorboard --logdir runs
